# %% [markdown]
# <h1>My Jupyter Notebook on IBM Data Science Experience</h1>

# %% [markdown]
# __Richard Rossmann__
# Data Analyst

# %% [markdown]
# *I am interested in data science because I love combining creativity with logic to solve complex problems.*

# %% [markdown]
# ### Simple Modulo (remainder) Arithmetic

# %%
27 % 5
# Out:
# 2

# %% [markdown]
# Here's an example of one of my ~~most liked~~ favourite charts, the **arc chart** (built using `R`):
# ![arc chart](http://revolution-computing.typepad.com/.a/6a010534b1db25970b01a5119af099970c-pi)
# ***
